# %%
import zastro as z
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt
import glob
from uncertainties import ufloat
import numpy as np
import pandas as pd
import os
import warnings
from scipy.optimize import OptimizeWarning
import matplotlib.gridspec as gridspec

# %%
def F(x, A_0,
      A_1, phi_1,A_2, phi_2,A_3, phi_3,A_4, phi_4,A_5, phi_5,A_6, phi_6,freq):
    return (A_0+A_1*np.sin(2*np.pi*1*freq*x+phi_1)+
                A_2*np.sin(2*np.pi*2*freq*x+phi_2)+
                A_3*np.sin(2*np.pi*3*freq*x+phi_3)+
                A_4*np.sin(2*np.pi*4*freq*x+phi_4)+
                A_5*np.sin(2*np.pi*5*freq*x+phi_5)+
                A_6*np.sin(2*np.pi*6*freq*x+phi_6))

# %%
objlist=glob.glob("EPIC*txt")

# %%
f=open("periodlistfileC0C1C2",'w')

for index, line in enumerate(objlist):

    print("###")
    print(line)
    print("###")
    
    resdict=z.csvtodict(objlist[index],skipheader=True,headers=['BJD','flux','EAPflux','fluxerror'])

    BJD=resdict['BJD'];flux=resdict['flux'];fluxerror=resdict['fluxerror']

    period=z.period(BJD,flux)

    LSPfreq=1/period

    pfit, pcov=optimize.curve_fit(lambda x, _A_0, 
                                      _A_1, _phi_1,
                                      _A_2, _phi_2,
                                      _A_3, _phi_3,
                                      _A_4, _phi_4,
                                      _A_5, _phi_5,
                                      _A_6, _phi_6,_freqfit:

                                      F(x, _A_0,_A_1, _phi_1,
                                                _A_2, _phi_2,
                                                _A_3, _phi_3,
                                                _A_4, _phi_4,
                                                _A_5, _phi_5,
                                                _A_6, _phi_6,_freqfit),

                                      BJD, flux, p0=[100, 100, 0,
                                                          100, 0,
                                                          100, 0,
                                                          100, 0,
                                                          100, 0,
                                                          100, 0,
                                                          LSPfreq],

                                                     sigma=fluxerror, absolute_sigma=True)

    error = [] # DEFINE LIST TO CALC ERROR
    for i in range(len(pfit)): 
        try:error.append(np.absolute(pcov[i][i])**0.5) # CALCULATE SQUARE ROOT OF TRACE OF COVARIANCE MATRIX
        except:error.append( 0.00 )     
    perr_curvefit = np.array(error)


    betterfreq=pfit[13]

    period=1/betterfreq

    f.write(objlist[index])
    f.write(" "+str(period)+"\n")

f.close()
# Out:
# ###
# EPIC_201775362-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_203802760-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_207720026-c00-eap.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.082
#  - Using 5 steps per peak; omega_step = 0.0164
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1644 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_202064530-c00-eap.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.462
#  - Using 5 steps per peak; omega_step = 0.0923
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 293 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_203097870-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201585823-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201720727-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201398311-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_201780233-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_203356808-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_204091956-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_203376043-c02-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201420867-c01-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201536956-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_203596258-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_203351697-c02-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_203780964-c02-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_201859140-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_203596245-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_201375063-c01-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201158092-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201866281-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_204115101-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_203480423-c02-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201685593-c01-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_202064526-c00-eap.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.082
#  - Using 5 steps per peak; omega_step = 0.0164
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1643 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201339783-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201488452-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_201828626-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_202064541-c00-eap.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.082
#  - Using 5 steps per peak; omega_step = 0.0164
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1643 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_203352471-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_201454019-c01-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_203692906-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201625638-c01-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_203630276-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_202858916-c02-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_203372915-c02-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_203693130-c02-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201716883-c01-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_203372256-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_201540013-c01-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_202064531-c00-eap.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.082
#  - Using 5 steps per peak; omega_step = 0.0164
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1643 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_202064491-c00-eap.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.082
#  - Using 5 steps per peak; omega_step = 0.0164
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1643 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_201195536-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_201288196-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_202064516-c00-eap.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.082
#  - Using 5 steps per peak; omega_step = 0.0164
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1643 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201191810-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_201786748-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_203369778-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_201901078-c01-k2sc.txt
# ###
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# ###
# EPIC_201905867-c01-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0784
#  - Using 5 steps per peak; omega_step = 0.0157
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1718 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# ###
# EPIC_203878283-c02-k2sc.txt
# ###
# Finding optimal frequency:
#  - Estimated peak width = 0.0808
#  - Using 5 steps per peak; omega_step = 0.0162
#  - User-specified period range:  0.2 to 1.4
#  - Computing periods at 1667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:728: RuntimeWarning: divide by zero encountered in true_divide
#   transform = 1.0 / sigma
# /home/pal/.local/lib/python3.6/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
